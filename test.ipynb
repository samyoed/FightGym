# %%
from itertools import combinations

# Walking directions and attack buttons as lists of lists
walking_directions = [["up"], ["down"], ["left"], ["right"], ["up", "left"], ["up", "right"], ["down", "left"], ["down", "right"]]
attack_buttons = [["one"], ["two"], ["three"], ["four"], ["one", "two"], ["one", "three"], ["one", "four"], ["two", "three"], ["two", "four"], ["three", "four"]]

# Combine the two lists for all possible combinations
combined_list = walking_directions + attack_buttons

# Generate all unique combinations of the combined list, taking 1 to the length of the combined list
all_combinations = []
for r in range(1, len(combined_list) + 1):
    all_combinations += [list(combination) for combination in combinations(combined_list, r)]

# Filter combinations to ensure each has at least one walking direction and one attack button
valid_combinations = []
for combination in all_combinations:
    if any(item in walking_directions for item in combination) and any(item in attack_buttons for item in combination):
        # Flatten the list and remove duplicates
        flattened = []
        for sublist in combination:
            for item in sublist:
                if item not in flattened:
                    flattened.append(item)
        valid_combinations.append(flattened)

# Limit the output for demonstration
limited_combinations = valid_combinations[:10]  # Showing only the first 10 for brevity

limited_combinations
# Out:
# [['up', 'one'],
#  ['up', 'two'],
#  ['up', 'three'],
#  ['up', 'four'],
#  ['up', 'one', 'two'],
#  ['up', 'one', 'three'],
#  ['up', 'one', 'four'],
#  ['up', 'two', 'three'],
#  ['up', 'two', 'four'],
#  ['up', 'three', 'four']]

# %%
# Format the combinations with their corresponding numbers starting from 18, as requested
formatted_combinations = {i+18: combo for i, combo in enumerate(valid_combinations)}

# Since the output can be very large, showing a limited preview again
preview_limit = 1000  # Adjust this number to show more or fewer examples
formatted_combinations_preview = {k: formatted_combinations[k] for k in list(formatted_combinations)[:preview_limit]}

formatted_combinations_preview
# Out:
# {18: ['up', 'one'],
#  19: ['up', 'two'],
#  20: ['up', 'three'],
#  21: ['up', 'four'],
#  22: ['up', 'one', 'two'],
#  23: ['up', 'one', 'three'],
#  24: ['up', 'one', 'four'],
#  25: ['up', 'two', 'three'],
#  26: ['up', 'two', 'four'],
#  27: ['up', 'three', 'four'],
#  28: ['down', 'one'],
#  29: ['down', 'two'],
#  30: ['down', 'three'],
#  31: ['down', 'four'],
#  32: ['down', 'one', 'two'],
#  33: ['down', 'one', 'three'],
#  34: ['down', 'one', 'four'],
#  35: ['down', 'two', 'three'],
#  36: ['down', 'two', 'four'],
#  37: ['down', 'three', 'four'],
#  38: ['left', 'one'],
#  39: ['left', 'two'],
#  40: ['left', 'three'],
#  41: ['left', 'four'],
#  42: ['left', 'one', 'two'],
#  43: ['left', 'one', 'three'],
#  44: ['left', 'one', 'four'],
#  45: ['left', 'two', 'three'],
#  46: ['left', 'two', 'four'],
#  47: ['left', 'three', 'four'],
#  48: ['right', 'one'],
#  49: ['right', 'two'],
#  50: ['right', 'three'],
#  51: ['right', 'four'],
#  52: ['right', 'one', 'two'],
#  53: ['right', 'one', 'three'],
#  54: ['right', 'one', 'four'],
#  55: ['right', 'two', 'three'],
#  56: ['right', 'two', 'four'],
#  57: ['right', 'three', 'four'],
#  58: ['up', 'left', 'one'],
#  59: ['up', 'left', 'two'],
#  60: ['up', 'left', 'three'],
#  61: ['up', 'left', 'four'],
#  62: ['up', 'left', 'one', 'two'],
#  63: ['up', 'left', 'one', 'three'],
#  64: ['up', 'left', 'one', 'four'],
#  65: ['up', 'left', 'two', 'three'],
#  66: ['up', 'left', 'two', 'four'],
#  67: ['up', 'left', 'three', 'four'],
#  68: ['up', 'right', 'one'],
#  69: ['up', 'right', 'two'],
#  70: ['up', 'right', 'three'],
#  71: ['up', 'right', 'four'],
#  72: ['up', 'right', 'one', 'two'],
#  73: ['up', 'right', 'one', 'three'],
#  74: ['up', 'right', 'one', 'four'],
#  75: ['up', 'right', 'two', 'three'],
#  76: ['up', 'right', 'two', 'four'],
#  77: ['up', 'right', 'three', 'four'],
#  78: ['down', 'left', 'one'],
#  79: ['down', 'left', 'two'],
#  80: ['down', 'left', 'three'],
#  81: ['down', 'left', 'four'],
#  82: ['down', 'left', 'one', 'two'],
#  83: ['down', 'left', 'one', 'three'],
#  84: ['down', 'left', 'one', 'four'],
#  85: ['down', 'left', 'two', 'three'],
#  86: ['down', 'left', 'two', 'four'],
#  87: ['down', 'left', 'three', 'four'],
#  88: ['down', 'right', 'one'],
#  89: ['down', 'right', 'two'],
#  90: ['down', 'right', 'three'],
#  91: ['down', 'right', 'four'],
#  92: ['down', 'right', 'one', 'two'],
#  93: ['down', 'right', 'one', 'three'],
#  94: ['down', 'right', 'one', 'four'],
#  95: ['down', 'right', 'two', 'three'],
#  96: ['down', 'right', 'two', 'four'],
#  97: ['down', 'right', 'three', 'four'],
#  98: ['up', 'down', 'one'],
#  99: ['up', 'down', 'two'],
#  100: ['up', 'down', 'three'],
#  101: ['up', 'down', 'four'],
#  102: ['up', 'down', 'one', 'two'],
#  103: ['up', 'down', 'one', 'three'],
#  104: ['up', 'down', 'one', 'four'],
#  105: ['up', 'down', 'two', 'three'],
#  106: ['up', 'down', 'two', 'four'],
#  107: ['up', 'down', 'three', 'four'],
#  108: ['up', 'left', 'one'],
#  109: ['up', 'left', 'two'],
#  110: ['up', 'left', 'three'],
#  111: ['up', 'left', 'four'],
#  112: ['up', 'left', 'one', 'two'],
#  113: ['up', 'left', 'one', 'three'],
#  114: ['up', 'left', 'one', 'four'],
#  115: ['up', 'left', 'two', 'three'],
#  116: ['up', 'left', 'two', 'four'],
#  117: ['up', 'left', 'three', 'four'],
#  118: ['up', 'right', 'one'],
#  119: ['up', 'right', 'two'],
#  120: ['up', 'right', 'three'],
#  121: ['up', 'right', 'four'],
#  122: ['up', 'right', 'one', 'two'],
#  123: ['up', 'right', 'one', 'three'],
#  124: ['up', 'right', 'one', 'four'],
#  125: ['up', 'right', 'two', 'three'],
#  126: ['up', 'right', 'two', 'four'],
#  127: ['up', 'right', 'three', 'four'],
#  128: ['up', 'left', 'one'],
#  129: ['up', 'left', 'two'],
#  130: ['up', 'left', 'three'],
#  131: ['up', 'left', 'four'],
#  132: ['up', 'left', 'one', 'two'],
#  133: ['up', 'left', 'one', 'three'],
#  134: ['up', 'left', 'one', 'four'],
#  135: ['up', 'left', 'two', 'three'],
#  136: ['up', 'left', 'two', 'four'],
#  137: ['up', 'left', 'three', 'four'],
#  138: ['up', 'right', 'one'],
#  139: ['up', 'right', 'two'],
#  140: ['up', 'right', 'three'],
#  141: ['up', 'right', 'four'],
#  142: ['up', 'right', 'one', 'two'],
#  143: ['up', 'right', 'one', 'three'],
#  144: ['up', 'right', 'one', 'four'],
#  145: ['up', 'right', 'two', 'three'],
#  146: ['up', 'right', 'two', 'four'],
#  147: ['up', 'right', 'three', 'four'],
#  148: ['up', 'down', 'left', 'one'],
#  149: ['up', 'down', 'left', 'two'],
#  150: ['up', 'down', 'left', 'three'],
#  151: ['up', 'down', 'left', 'four'],
#  152: ['up', 'down', 'left', 'one', 'two'],
#  153: ['up', 'down', 'left', 'one', 'three'],
#  154: ['up', 'down', 'left', 'one', 'four'],
#  155: ['up', 'down', 'left', 'two', 'three'],
#  156: ['up', 'down', 'left', 'two', 'four'],
#  157: ['up', 'down', 'left', 'three', 'four'],
#  158: ['up', 'down', 'right', 'one'],
#  159: ['up', 'down', 'right', 'two'],
#  160: ['up', 'down', 'right', 'three'],
#  161: ['up', 'down', 'right', 'four'],
#  162: ['up', 'down', 'right', 'one', 'two'],
#  163: ['up', 'down', 'right', 'one', 'three'],
#  164: ['up', 'down', 'right', 'one', 'four'],
#  165: ['up', 'down', 'right', 'two', 'three'],
#  166: ['up', 'down', 'right', 'two', 'four'],
#  167: ['up', 'down', 'right', 'three', 'four'],
#  168: ['up', 'one', 'two'],
#  169: ['up', 'one', 'three'],
#  170: ['up', 'one', 'four'],
#  171: ['up', 'one', 'two'],
#  172: ['up', 'one', 'three'],
#  173: ['up', 'one', 'four'],
#  174: ['up', 'one', 'two', 'three'],
#  175: ['up', 'one', 'two', 'four'],
#  176: ['up', 'one', 'three', 'four'],
#  177: ['up', 'two', 'three'],
#  178: ['up', 'two', 'four'],
#  179: ['up', 'two', 'one'],
#  180: ['up', 'two', 'one', 'three'],
#  181: ['up', 'two', 'one', 'four'],
#  182: ['up', 'two', 'three'],
#  183: ['up', 'two', 'four'],
#  184: ['up', 'two', 'three', 'four'],
#  185: ['up', 'three', 'four'],
#  186: ['up', 'three', 'one', 'two'],
#  187: ['up', 'three', 'one'],
#  188: ['up', 'three', 'one', 'four'],
#  189: ['up', 'three', 'two'],
#  190: ['up', 'three', 'two', 'four'],
#  191: ['up', 'three', 'four'],
#  192: ['up', 'four', 'one', 'two'],
#  193: ['up', 'four', 'one', 'three'],
#  194: ['up', 'four', 'one'],
#  195: ['up', 'four', 'two', 'three'],
#  196: ['up', 'four', 'two'],
#  197: ['up', 'four', 'three'],
#  198: ['up', 'one', 'two', 'three'],
#  199: ['up', 'one', 'two', 'four'],
#  200: ['up', 'one', 'two', 'three'],
#  201: ['up', 'one', 'two', 'four'],
#  202: ['up', 'one', 'two', 'three', 'four'],
#  203: ['up', 'one', 'three', 'four'],
#  204: ['up', 'one', 'three', 'two'],
#  205: ['up', 'one', 'three', 'two', 'four'],
#  206: ['up', 'one', 'three', 'four'],
#  207: ['up', 'one', 'four', 'two', 'three'],
#  208: ['up', 'one', 'four', 'two'],
#  209: ['up', 'one', 'four', 'three'],
#  210: ['up', 'two', 'three', 'four'],
#  211: ['up', 'two', 'three', 'four'],
#  212: ['up', 'two', 'four', 'three'],
#  213: ['down', 'left', 'one'],
#  214: ['down', 'left', 'two'],
#  215: ['down', 'left', 'three'],
#  216: ['down', 'left', 'four'],
#  217: ['down', 'left', 'one', 'two'],
#  218: ['down', 'left', 'one', 'three'],
#  219: ['down', 'left', 'one', 'four'],
#  220: ['down', 'left', 'two', 'three'],
#  221: ['down', 'left', 'two', 'four'],
#  222: ['down', 'left', 'three', 'four'],
#  223: ['down', 'right', 'one'],
#  224: ['down', 'right', 'two'],
#  225: ['down', 'right', 'three'],
#  226: ['down', 'right', 'four'],
#  227: ['down', 'right', 'one', 'two'],
#  228: ['down', 'right', 'one', 'three'],
#  229: ['down', 'right', 'one', 'four'],
#  230: ['down', 'right', 'two', 'three'],
#  231: ['down', 'right', 'two', 'four'],
#  232: ['down', 'right', 'three', 'four'],
#  233: ['down', 'up', 'left', 'one'],
#  234: ['down', 'up', 'left', 'two'],
#  235: ['down', 'up', 'left', 'three'],
#  236: ['down', 'up', 'left', 'four'],
#  237: ['down', 'up', 'left', 'one', 'two'],
#  238: ['down', 'up', 'left', 'one', 'three'],
#  239: ['down', 'up', 'left', 'one', 'four'],
#  240: ['down', 'up', 'left', 'two', 'three'],
#  241: ['down', 'up', 'left', 'two', 'four'],
#  242: ['down', 'up', 'left', 'three', 'four'],
#  243: ['down', 'up', 'right', 'one'],
#  244: ['down', 'up', 'right', 'two'],
#  245: ['down', 'up', 'right', 'three'],
#  246: ['down', 'up', 'right', 'four'],
#  247: ['down', 'up', 'right', 'one', 'two'],
#  248: ['down', 'up', 'right', 'one', 'three'],
#  249: ['down', 'up', 'right', 'one', 'four'],
#  250: ['down', 'up', 'right', 'two', 'three'],
#  251: ['down', 'up', 'right', 'two', 'four'],
#  252: ['down', 'up', 'right', 'three', 'four'],
#  253: ['down', 'left', 'one'],
#  254: ['down', 'left', 'two'],
#  255: ['down', 'left', 'three'],
#  256: ['down', 'left', 'four'],
#  257: ['down', 'left', 'one', 'two'],
#  258: ['down', 'left', 'one', 'three'],
#  259: ['down', 'left', 'one', 'four'],
#  260: ['down', 'left', 'two', 'three'],
#  261: ['down', 'left', 'two', 'four'],
#  262: ['down', 'left', 'three', 'four'],
#  263: ['down', 'right', 'one'],
#  264: ['down', 'right', 'two'],
#  265: ['down', 'right', 'three'],
#  266: ['down', 'right', 'four'],
#  267: ['down', 'right', 'one', 'two'],
#  268: ['down', 'right', 'one', 'three'],
#  269: ['down', 'right', 'one', 'four'],
#  270: ['down', 'right', 'two', 'three'],
#  271: ['down', 'right', 'two', 'four'],
#  272: ['down', 'right', 'three', 'four'],
#  273: ['down', 'one', 'two'],
#  274: ['down', 'one', 'three'],
#  275: ['down', 'one', 'four'],
#  276: ['down', 'one', 'two'],
#  277: ['down', 'one', 'three'],
#  278: ['down', 'one', 'four'],
#  279: ['down', 'one', 'two', 'three'],
#  280: ['down', 'one', 'two', 'four'],
#  281: ['down', 'one', 'three', 'four'],
#  282: ['down', 'two', 'three'],
#  283: ['down', 'two', 'four'],
#  284: ['down', 'two', 'one'],
#  285: ['down', 'two', 'one', 'three'],
#  286: ['down', 'two', 'one', 'four'],
#  287: ['down', 'two', 'three'],
#  288: ['down', 'two', 'four'],
#  289: ['down', 'two', 'three', 'four'],
#  290: ['down', 'three', 'four'],
#  291: ['down', 'three', 'one', 'two'],
#  292: ['down', 'three', 'one'],
#  293: ['down', 'three', 'one', 'four'],
#  294: ['down', 'three', 'two'],
#  295: ['down', 'three', 'two', 'four'],
#  296: ['down', 'three', 'four'],
#  297: ['down', 'four', 'one', 'two'],
#  298: ['down', 'four', 'one', 'three'],
#  299: ['down', 'four', 'one'],
#  300: ['down', 'four', 'two', 'three'],
#  301: ['down', 'four', 'two'],
#  302: ['down', 'four', 'three'],
#  303: ['down', 'one', 'two', 'three'],
#  304: ['down', 'one', 'two', 'four'],
#  305: ['down', 'one', 'two', 'three'],
#  306: ['down', 'one', 'two', 'four'],
#  307: ['down', 'one', 'two', 'three', 'four'],
#  308: ['down', 'one', 'three', 'four'],
#  309: ['down', 'one', 'three', 'two'],
#  310: ['down', 'one', 'three', 'two', 'four'],
#  311: ['down', 'one', 'three', 'four'],
#  312: ['down', 'one', 'four', 'two', 'three'],
#  313: ['down', 'one', 'four', 'two'],
#  314: ['down', 'one', 'four', 'three'],
#  315: ['down', 'two', 'three', 'four'],
#  316: ['down', 'two', 'three', 'four'],
#  317: ['down', 'two', 'four', 'three'],
#  318: ['left', 'right', 'one'],
#  319: ['left', 'right', 'two'],
#  320: ['left', 'right', 'three'],
#  321: ['left', 'right', 'four'],
#  322: ['left', 'right', 'one', 'two'],
#  323: ['left', 'right', 'one', 'three'],
#  324: ['left', 'right', 'one', 'four'],
#  325: ['left', 'right', 'two', 'three'],
#  326: ['left', 'right', 'two', 'four'],
#  327: ['left', 'right', 'three', 'four'],
#  328: ['left', 'up', 'one'],
#  329: ['left', 'up', 'two'],
#  330: ['left', 'up', 'three'],
#  331: ['left', 'up', 'four'],
#  332: ['left', 'up', 'one', 'two'],
#  333: ['left', 'up', 'one', 'three'],
#  334: ['left', 'up', 'one', 'four'],
#  335: ['left', 'up', 'two', 'three'],
#  336: ['left', 'up', 'two', 'four'],
#  337: ['left', 'up', 'three', 'four'],
#  338: ['left', 'up', 'right', 'one'],
#  339: ['left', 'up', 'right', 'two'],
#  340: ['left', 'up', 'right', 'three'],
#  341: ['left', 'up', 'right', 'four'],
#  342: ['left', 'up', 'right', 'one', 'two'],
#  343: ['left', 'up', 'right', 'one', 'three'],
#  344: ['left', 'up', 'right', 'one', 'four'],
#  345: ['left', 'up', 'right', 'two', 'three'],
#  346: ['left', 'up', 'right', 'two', 'four'],
#  347: ['left', 'up', 'right', 'three', 'four'],
#  348: ['left', 'down', 'one'],
#  349: ['left', 'down', 'two'],
#  350: ['left', 'down', 'three'],
#  351: ['left', 'down', 'four'],
#  352: ['left', 'down', 'one', 'two'],
#  353: ['left', 'down', 'one', 'three'],
#  354: ['left', 'down', 'one', 'four'],
#  355: ['left', 'down', 'two', 'three'],
#  356: ['left', 'down', 'two', 'four'],
#  357: ['left', 'down', 'three', 'four'],
#  358: ['left', 'down', 'right', 'one'],
#  359: ['left', 'down', 'right', 'two'],
#  360: ['left', 'down', 'right', 'three'],
#  361: ['left', 'down', 'right', 'four'],
#  362: ['left', 'down', 'right', 'one', 'two'],
#  363: ['left', 'down', 'right', 'one', 'three'],
#  364: ['left', 'down', 'right', 'one', 'four'],
#  365: ['left', 'down', 'right', 'two', 'three'],
#  366: ['left', 'down', 'right', 'two', 'four'],
#  367: ['left', 'down', 'right', 'three', 'four'],
#  368: ['left', 'one', 'two'],
#  369: ['left', 'one', 'three'],
#  370: ['left', 'one', 'four'],
#  371: ['left', 'one', 'two'],
#  372: ['left', 'one', 'three'],
#  373: ['left', 'one', 'four'],
#  374: ['left', 'one', 'two', 'three'],
#  375: ['left', 'one', 'two', 'four'],
#  376: ['left', 'one', 'three', 'four'],
#  377: ['left', 'two', 'three'],
#  378: ['left', 'two', 'four'],
#  379: ['left', 'two', 'one'],
#  380: ['left', 'two', 'one', 'three'],
#  381: ['left', 'two', 'one', 'four'],
#  382: ['left', 'two', 'three'],
#  383: ['left', 'two', 'four'],
#  384: ['left', 'two', 'three', 'four'],
#  385: ['left', 'three', 'four'],
#  386: ['left', 'three', 'one', 'two'],
#  387: ['left', 'three', 'one'],
#  388: ['left', 'three', 'one', 'four'],
#  389: ['left', 'three', 'two'],
#  390: ['left', 'three', 'two', 'four'],
#  391: ['left', 'three', 'four'],
#  392: ['left', 'four', 'one', 'two'],
#  393: ['left', 'four', 'one', 'three'],
#  394: ['left', 'four', 'one'],
#  395: ['left', 'four', 'two', 'three'],
#  396: ['left', 'four', 'two'],
#  397: ['left', 'four', 'three'],
#  398: ['left', 'one', 'two', 'three'],
#  399: ['left', 'one', 'two', 'four'],
#  400: ['left', 'one', 'two', 'three'],
#  401: ['left', 'one', 'two', 'four'],
#  402: ['left', 'one', 'two', 'three', 'four'],
#  403: ['left', 'one', 'three', 'four'],
#  404: ['left', 'one', 'three', 'two'],
#  405: ['left', 'one', 'three', 'two', 'four'],
#  406: ['left', 'one', 'three', 'four'],
#  407: ['left', 'one', 'four', 'two', 'three'],
#  408: ['left', 'one', 'four', 'two'],
#  409: ['left', 'one', 'four', 'three'],
#  410: ['left', 'two', 'three', 'four'],
#  411: ['left', 'two', 'three', 'four'],
#  412: ['left', 'two', 'four', 'three'],
#  413: ['right', 'up', 'left', 'one'],
#  414: ['right', 'up', 'left', 'two'],
#  415: ['right', 'up', 'left', 'three'],
#  416: ['right', 'up', 'left', 'four'],
#  417: ['right', 'up', 'left', 'one', 'two'],
#  418: ['right', 'up', 'left', 'one', 'three'],
#  419: ['right', 'up', 'left', 'one', 'four'],
#  420: ['right', 'up', 'left', 'two', 'three'],
#  421: ['right', 'up', 'left', 'two', 'four'],
#  422: ['right', 'up', 'left', 'three', 'four'],
#  423: ['right', 'up', 'one'],
#  424: ['right', 'up', 'two'],
#  425: ['right', 'up', 'three'],
#  426: ['right', 'up', 'four'],
#  427: ['right', 'up', 'one', 'two'],
#  428: ['right', 'up', 'one', 'three'],
#  429: ['right', 'up', 'one', 'four'],
#  430: ['right', 'up', 'two', 'three'],
#  431: ['right', 'up', 'two', 'four'],
#  432: ['right', 'up', 'three', 'four'],
#  433: ['right', 'down', 'left', 'one'],
#  434: ['right', 'down', 'left', 'two'],
#  435: ['right', 'down', 'left', 'three'],
#  436: ['right', 'down', 'left', 'four'],
#  437: ['right', 'down', 'left', 'one', 'two'],
#  438: ['right', 'down', 'left', 'one', 'three'],
#  439: ['right', 'down', 'left', 'one', 'four'],
#  440: ['right', 'down', 'left', 'two', 'three'],
#  441: ['right', 'down', 'left', 'two', 'four'],
#  442: ['right', 'down', 'left', 'three', 'four'],
#  443: ['right', 'down', 'one'],
#  444: ['right', 'down', 'two'],
#  445: ['right', 'down', 'three'],
#  446: ['right', 'down', 'four'],
#  447: ['right', 'down', 'one', 'two'],
#  448: ['right', 'down', 'one', 'three'],
#  449: ['right', 'down', 'one', 'four'],
#  450: ['right', 'down', 'two', 'three'],
#  451: ['right', 'down', 'two', 'four'],
#  452: ['right', 'down', 'three', 'four'],
#  453: ['right', 'one', 'two'],
#  454: ['right', 'one', 'three'],
#  455: ['right', 'one', 'four'],
#  456: ['right', 'one', 'two'],
#  457: ['right', 'one', 'three'],
#  458: ['right', 'one', 'four'],
#  459: ['right', 'one', 'two', 'three'],
#  460: ['right', 'one', 'two', 'four'],
#  461: ['right', 'one', 'three', 'four'],
#  462: ['right', 'two', 'three'],
#  463: ['right', 'two', 'four'],
#  464: ['right', 'two', 'one'],
#  465: ['right', 'two', 'one', 'three'],
#  466: ['right', 'two', 'one', 'four'],
#  467: ['right', 'two', 'three'],
#  468: ['right', 'two', 'four'],
#  469: ['right', 'two', 'three', 'four'],
#  470: ['right', 'three', 'four'],
#  471: ['right', 'three', 'one', 'two'],
#  472: ['right', 'three', 'one'],
#  473: ['right', 'three', 'one', 'four'],
#  474: ['right', 'three', 'two'],
#  475: ['right', 'three', 'two', 'four'],
#  476: ['right', 'three', 'four'],
#  477: ['right', 'four', 'one', 'two'],
#  478: ['right', 'four', 'one', 'three'],
#  479: ['right', 'four', 'one'],
#  480: ['right', 'four', 'two', 'three'],
#  481: ['right', 'four', 'two'],
#  482: ['right', 'four', 'three'],
#  483: ['right', 'one', 'two', 'three'],
#  484: ['right', 'one', 'two', 'four'],
#  485: ['right', 'one', 'two', 'three'],
#  486: ['right', 'one', 'two', 'four'],
#  487: ['right', 'one', 'two', 'three', 'four'],
#  488: ['right', 'one', 'three', 'four'],
#  489: ['right', 'one', 'three', 'two'],
#  490: ['right', 'one', 'three', 'two', 'four'],
#  491: ['right', 'one', 'three', 'four'],
#  492: ['right', 'one', 'four', 'two', 'three'],
#  493: ['right', 'one', 'four', 'two'],
#  494: ['right', 'one', 'four', 'three'],
#  495: ['right', 'two', 'three', 'four'],
#  496: ['right', 'two', 'three', 'four'],
#  497: ['right', 'two', 'four', 'three'],
#  498: ['up', 'left', 'right', 'one'],
#  499: ['up', 'left', 'right', 'two'],
#  500: ['up', 'left', 'right', 'three'],
#  501: ['up', 'left', 'right', 'four'],
#  502: ['up', 'left', 'right', 'one', 'two'],
#  503: ['up', 'left', 'right', 'one', 'three'],
#  504: ['up', 'left', 'right', 'one', 'four'],
#  505: ['up', 'left', 'right', 'two', 'three'],
#  506: ['up', 'left', 'right', 'two', 'four'],
#  507: ['up', 'left', 'right', 'three', 'four'],
#  508: ['up', 'left', 'down', 'one'],
#  509: ['up', 'left', 'down', 'two'],
#  510: ['up', 'left', 'down', 'three'],
#  511: ['up', 'left', 'down', 'four'],
#  512: ['up', 'left', 'down', 'one', 'two'],
#  513: ['up', 'left', 'down', 'one', 'three'],
#  514: ['up', 'left', 'down', 'one', 'four'],
#  515: ['up', 'left', 'down', 'two', 'three'],
#  516: ['up', 'left', 'down', 'two', 'four'],
#  517: ['up', 'left', 'down', 'three', 'four'],
#  518: ['up', 'left', 'down', 'right', 'one'],
#  519: ['up', 'left', 'down', 'right', 'two'],
#  520: ['up', 'left', 'down', 'right', 'three'],
#  521: ['up', 'left', 'down', 'right', 'four'],
#  522: ['up', 'left', 'down', 'right', 'one', 'two'],
#  523: ['up', 'left', 'down', 'right', 'one', 'three'],
#  524: ['up', 'left', 'down', 'right', 'one', 'four'],
#  525: ['up', 'left', 'down', 'right', 'two', 'three'],
#  526: ['up', 'left', 'down', 'right', 'two', 'four'],
#  527: ['up', 'left', 'down', 'right', 'three', 'four'],
#  528: ['up', 'left', 'one', 'two'],
#  529: ['up', 'left', 'one', 'three'],
#  530: ['up', 'left', 'one', 'four'],
#  531: ['up', 'left', 'one', 'two'],
#  532: ['up', 'left', 'one', 'three'],
#  533: ['up', 'left', 'one', 'four'],
#  534: ['up', 'left', 'one', 'two', 'three'],
#  535: ['up', 'left', 'one', 'two', 'four'],
#  536: ['up', 'left', 'one', 'three', 'four'],
#  537: ['up', 'left', 'two', 'three'],
#  538: ['up', 'left', 'two', 'four'],
#  539: ['up', 'left', 'two', 'one'],
#  540: ['up', 'left', 'two', 'one', 'three'],
#  541: ['up', 'left', 'two', 'one', 'four'],
#  542: ['up', 'left', 'two', 'three'],
#  543: ['up', 'left', 'two', 'four'],
#  544: ['up', 'left', 'two', 'three', 'four'],
#  545: ['up', 'left', 'three', 'four'],
#  546: ['up', 'left', 'three', 'one', 'two'],
#  547: ['up', 'left', 'three', 'one'],
#  548: ['up', 'left', 'three', 'one', 'four'],
#  549: ['up', 'left', 'three', 'two'],
#  550: ['up', 'left', 'three', 'two', 'four'],
#  551: ['up', 'left', 'three', 'four'],
#  552: ['up', 'left', 'four', 'one', 'two'],
#  553: ['up', 'left', 'four', 'one', 'three'],
#  554: ['up', 'left', 'four', 'one'],
#  555: ['up', 'left', 'four', 'two', 'three'],
#  556: ['up', 'left', 'four', 'two'],
#  557: ['up', 'left', 'four', 'three'],
#  558: ['up', 'left', 'one', 'two', 'three'],
#  559: ['up', 'left', 'one', 'two', 'four'],
#  560: ['up', 'left', 'one', 'two', 'three'],
#  561: ['up', 'left', 'one', 'two', 'four'],
#  562: ['up', 'left', 'one', 'two', 'three', 'four'],
#  563: ['up', 'left', 'one', 'three', 'four'],
#  564: ['up', 'left', 'one', 'three', 'two'],
#  565: ['up', 'left', 'one', 'three', 'two', 'four'],
#  566: ['up', 'left', 'one', 'three', 'four'],
#  567: ['up', 'left', 'one', 'four', 'two', 'three'],
#  568: ['up', 'left', 'one', 'four', 'two'],
#  569: ['up', 'left', 'one', 'four', 'three'],
#  570: ['up', 'left', 'two', 'three', 'four'],
#  571: ['up', 'left', 'two', 'three', 'four'],
#  572: ['up', 'left', 'two', 'four', 'three'],
#  573: ['up', 'right', 'down', 'left', 'one'],
#  574: ['up', 'right', 'down', 'left', 'two'],
#  575: ['up', 'right', 'down', 'left', 'three'],
#  576: ['up', 'right', 'down', 'left', 'four'],
#  577: ['up', 'right', 'down', 'left', 'one', 'two'],
#  578: ['up', 'right', 'down', 'left', 'one', 'three'],
#  579: ['up', 'right', 'down', 'left', 'one', 'four'],
#  580: ['up', 'right', 'down', 'left', 'two', 'three'],
#  581: ['up', 'right', 'down', 'left', 'two', 'four'],
#  582: ['up', 'right', 'down', 'left', 'three', 'four'],
#  583: ['up', 'right', 'down', 'one'],
#  584: ['up', 'right', 'down', 'two'],
#  585: ['up', 'right', 'down', 'three'],
#  586: ['up', 'right', 'down', 'four'],
#  587: ['up', 'right', 'down', 'one', 'two'],
#  588: ['up', 'right', 'down', 'one', 'three'],
#  589: ['up', 'right', 'down', 'one', 'four'],
#  590: ['up', 'right', 'down', 'two', 'three'],
#  591: ['up', 'right', 'down', 'two', 'four'],
#  592: ['up', 'right', 'down', 'three', 'four'],
#  593: ['up', 'right', 'one', 'two'],
#  594: ['up', 'right', 'one', 'three'],
#  595: ['up', 'right', 'one', 'four'],
#  596: ['up', 'right', 'one', 'two'],
#  597: ['up', 'right', 'one', 'three'],
#  598: ['up', 'right', 'one', 'four'],
#  599: ['up', 'right', 'one', 'two', 'three'],
#  600: ['up', 'right', 'one', 'two', 'four'],
#  601: ['up', 'right', 'one', 'three', 'four'],
#  602: ['up', 'right', 'two', 'three'],
#  603: ['up', 'right', 'two', 'four'],
#  604: ['up', 'right', 'two', 'one'],
#  605: ['up', 'right', 'two', 'one', 'three'],
#  606: ['up', 'right', 'two', 'one', 'four'],
#  607: ['up', 'right', 'two', 'three'],
#  608: ['up', 'right', 'two', 'four'],
#  609: ['up', 'right', 'two', 'three', 'four'],
#  610: ['up', 'right', 'three', 'four'],
#  611: ['up', 'right', 'three', 'one', 'two'],
#  612: ['up', 'right', 'three', 'one'],
#  613: ['up', 'right', 'three', 'one', 'four'],
#  614: ['up', 'right', 'three', 'two'],
#  615: ['up', 'right', 'three', 'two', 'four'],
#  616: ['up', 'right', 'three', 'four'],
#  617: ['up', 'right', 'four', 'one', 'two'],
#  618: ['up', 'right', 'four', 'one', 'three'],
#  619: ['up', 'right', 'four', 'one'],
#  620: ['up', 'right', 'four', 'two', 'three'],
#  621: ['up', 'right', 'four', 'two'],
#  622: ['up', 'right', 'four', 'three'],
#  623: ['up', 'right', 'one', 'two', 'three'],
#  624: ['up', 'right', 'one', 'two', 'four'],
#  625: ['up', 'right', 'one', 'two', 'three'],
#  626: ['up', 'right', 'one', 'two', 'four'],
#  627: ['up', 'right', 'one', 'two', 'three', 'four'],
#  628: ['up', 'right', 'one', 'three', 'four'],
#  629: ['up', 'right', 'one', 'three', 'two'],
#  630: ['up', 'right', 'one', 'three', 'two', 'four'],
#  631: ['up', 'right', 'one', 'three', 'four'],
#  632: ['up', 'right', 'one', 'four', 'two', 'three'],
#  633: ['up', 'right', 'one', 'four', 'two'],
#  634: ['up', 'right', 'one', 'four', 'three'],
#  635: ['up', 'right', 'two', 'three', 'four'],
#  636: ['up', 'right', 'two', 'three', 'four'],
#  637: ['up', 'right', 'two', 'four', 'three'],
#  638: ['down', 'left', 'right', 'one'],
#  639: ['down', 'left', 'right', 'two'],
#  640: ['down', 'left', 'right', 'three'],
#  641: ['down', 'left', 'right', 'four'],
#  642: ['down', 'left', 'right', 'one', 'two'],
#  643: ['down', 'left', 'right', 'one', 'three'],
#  644: ['down', 'left', 'right', 'one', 'four'],
#  645: ['down', 'left', 'right', 'two', 'three'],
#  646: ['down', 'left', 'right', 'two', 'four'],
#  647: ['down', 'left', 'right', 'three', 'four'],
#  648: ['down', 'left', 'one', 'two'],
#  649: ['down', 'left', 'one', 'three'],
#  650: ['down', 'left', 'one', 'four'],
#  651: ['down', 'left', 'one', 'two'],
#  652: ['down', 'left', 'one', 'three'],
#  653: ['down', 'left', 'one', 'four'],
#  654: ['down', 'left', 'one', 'two', 'three'],
#  655: ['down', 'left', 'one', 'two', 'four'],
#  656: ['down', 'left', 'one', 'three', 'four'],
#  657: ['down', 'left', 'two', 'three'],
#  658: ['down', 'left', 'two', 'four'],
#  659: ['down', 'left', 'two', 'one'],
#  660: ['down', 'left', 'two', 'one', 'three'],
#  661: ['down', 'left', 'two', 'one', 'four'],
#  662: ['down', 'left', 'two', 'three'],
#  663: ['down', 'left', 'two', 'four'],
#  664: ['down', 'left', 'two', 'three', 'four'],
#  665: ['down', 'left', 'three', 'four'],
#  666: ['down', 'left', 'three', 'one', 'two'],
#  667: ['down', 'left', 'three', 'one'],
#  668: ['down', 'left', 'three', 'one', 'four'],
#  669: ['down', 'left', 'three', 'two'],
#  670: ['down', 'left', 'three', 'two', 'four'],
#  671: ['down', 'left', 'three', 'four'],
#  672: ['down', 'left', 'four', 'one', 'two'],
#  673: ['down', 'left', 'four', 'one', 'three'],
#  674: ['down', 'left', 'four', 'one'],
#  675: ['down', 'left', 'four', 'two', 'three'],
#  676: ['down', 'left', 'four', 'two'],
#  677: ['down', 'left', 'four', 'three'],
#  678: ['down', 'left', 'one', 'two', 'three'],
#  679: ['down', 'left', 'one', 'two', 'four'],
#  680: ['down', 'left', 'one', 'two', 'three'],
#  681: ['down', 'left', 'one', 'two', 'four'],
#  682: ['down', 'left', 'one', 'two', 'three', 'four'],
#  683: ['down', 'left', 'one', 'three', 'four'],
#  684: ['down', 'left', 'one', 'three', 'two'],
#  685: ['down', 'left', 'one', 'three', 'two', 'four'],
#  686: ['down', 'left', 'one', 'three', 'four'],
#  687: ['down', 'left', 'one', 'four', 'two', 'three'],
#  688: ['down', 'left', 'one', 'four', 'two'],
#  689: ['down', 'left', 'one', 'four', 'three'],
#  690: ['down', 'left', 'two', 'three', 'four'],
#  691: ['down', 'left', 'two', 'three', 'four'],
#  692: ['down', 'left', 'two', 'four', 'three'],
#  693: ['down', 'right', 'one', 'two'],
#  694: ['down', 'right', 'one', 'three'],
#  695: ['down', 'right', 'one', 'four'],
#  696: ['down', 'right', 'one', 'two'],
#  697: ['down', 'right', 'one', 'three'],
#  698: ['down', 'right', 'one', 'four'],
#  699: ['down', 'right', 'one', 'two', 'three'],
#  700: ['down', 'right', 'one', 'two', 'four'],
#  701: ['down', 'right', 'one', 'three', 'four'],
#  702: ['down', 'right', 'two', 'three'],
#  703: ['down', 'right', 'two', 'four'],
#  704: ['down', 'right', 'two', 'one'],
#  705: ['down', 'right', 'two', 'one', 'three'],
#  706: ['down', 'right', 'two', 'one', 'four'],
#  707: ['down', 'right', 'two', 'three'],
#  708: ['down', 'right', 'two', 'four'],
#  709: ['down', 'right', 'two', 'three', 'four'],
#  710: ['down', 'right', 'three', 'four'],
#  711: ['down', 'right', 'three', 'one', 'two'],
#  712: ['down', 'right', 'three', 'one'],
#  713: ['down', 'right', 'three', 'one', 'four'],
#  714: ['down', 'right', 'three', 'two'],
#  715: ['down', 'right', 'three', 'two', 'four'],
#  716: ['down', 'right', 'three', 'four'],
#  717: ['down', 'right', 'four', 'one', 'two'],
#  718: ['down', 'right', 'four', 'one', 'three'],
#  719: ['down', 'right', 'four', 'one'],
#  720: ['down', 'right', 'four', 'two', 'three'],
#  721: ['down', 'right', 'four', 'two'],
#  722: ['down', 'right', 'four', 'three'],
#  723: ['down', 'right', 'one', 'two', 'three'],
#  724: ['down', 'right', 'one', 'two', 'four'],
#  725: ['down', 'right', 'one', 'two', 'three'],
#  726: ['down', 'right', 'one', 'two', 'four'],
#  727: ['down', 'right', 'one', 'two', 'three', 'four'],
#  728: ['down', 'right', 'one', 'three', 'four'],
#  729: ['down', 'right', 'one', 'three', 'two'],
#  730: ['down', 'right', 'one', 'three', 'two', 'four'],
#  731: ['down', 'right', 'one', 'three', 'four'],
#  732: ['down', 'right', 'one', 'four', 'two', 'three'],
#  733: ['down', 'right', 'one', 'four', 'two'],
#  734: ['down', 'right', 'one', 'four', 'three'],
#  735: ['down', 'right', 'two', 'three', 'four'],
#  736: ['down', 'right', 'two', 'three', 'four'],
#  737: ['down', 'right', 'two', 'four', 'three'],
#  738: ['up', 'down', 'left', 'one'],
#  739: ['up', 'down', 'left', 'two'],
#  740: ['up', 'down', 'left', 'three'],
#  741: ['up', 'down', 'left', 'four'],
#  742: ['up', 'down', 'left', 'one', 'two'],
#  743: ['up', 'down', 'left', 'one', 'three'],
#  744: ['up', 'down', 'left', 'one', 'four'],
#  745: ['up', 'down', 'left', 'two', 'three'],
#  746: ['up', 'down', 'left', 'two', 'four'],
#  747: ['up', 'down', 'left', 'three', 'four'],
#  748: ['up', 'down', 'right', 'one'],
#  749: ['up', 'down', 'right', 'two'],
#  750: ['up', 'down', 'right', 'three'],
#  751: ['up', 'down', 'right', 'four'],
#  752: ['up', 'down', 'right', 'one', 'two'],
#  753: ['up', 'down', 'right', 'one', 'three'],
#  754: ['up', 'down', 'right', 'one', 'four'],
#  755: ['up', 'down', 'right', 'two', 'three'],
#  756: ['up', 'down', 'right', 'two', 'four'],
#  757: ['up', 'down', 'right', 'three', 'four'],
#  758: ['up', 'down', 'left', 'one'],
#  759: ['up', 'down', 'left', 'two'],
#  760: ['up', 'down', 'left', 'three'],
#  761: ['up', 'down', 'left', 'four'],
#  762: ['up', 'down', 'left', 'one', 'two'],
#  763: ['up', 'down', 'left', 'one', 'three'],
#  764: ['up', 'down', 'left', 'one', 'four'],
#  765: ['up', 'down', 'left', 'two', 'three'],
#  766: ['up', 'down', 'left', 'two', 'four'],
#  767: ['up', 'down', 'left', 'three', 'four'],
#  768: ['up', 'down', 'right', 'one'],
#  769: ['up', 'down', 'right', 'two'],
#  770: ['up', 'down', 'right', 'three'],
#  771: ['up', 'down', 'right', 'four'],
#  772: ['up', 'down', 'right', 'one', 'two'],
#  773: ['up', 'down', 'right', 'one', 'three'],
#  774: ['up', 'down', 'right', 'one', 'four'],
#  775: ['up', 'down', 'right', 'two', 'three'],
#  776: ['up', 'down', 'right', 'two', 'four'],
#  777: ['up', 'down', 'right', 'three', 'four'],
#  778: ['up', 'down', 'left', 'one'],
#  779: ['up', 'down', 'left', 'two'],
#  780: ['up', 'down', 'left', 'three'],
#  781: ['up', 'down', 'left', 'four'],
#  782: ['up', 'down', 'left', 'one', 'two'],
#  783: ['up', 'down', 'left', 'one', 'three'],
#  784: ['up', 'down', 'left', 'one', 'four'],
#  785: ['up', 'down', 'left', 'two', 'three'],
#  786: ['up', 'down', 'left', 'two', 'four'],
#  787: ['up', 'down', 'left', 'three', 'four'],
#  788: ['up', 'down', 'right', 'one'],
#  789: ['up', 'down', 'right', 'two'],
#  790: ['up', 'down', 'right', 'three'],
#  791: ['up', 'down', 'right', 'four'],
#  792: ['up', 'down', 'right', 'one', 'two'],
#  793: ['up', 'down', 'right', 'one', 'three'],
#  794: ['up', 'down', 'right', 'one', 'four'],
#  795: ['up', 'down', 'right', 'two', 'three'],
#  796: ['up', 'down', 'right', 'two', 'four'],
#  797: ['up', 'down', 'right', 'three', 'four'],
#  798: ['up', 'down', 'one', 'two'],
#  799: ['up', 'down', 'one', 'three'],
#  800: ['up', 'down', 'one', 'four'],
#  801: ['up', 'down', 'one', 'two'],
#  802: ['up', 'down', 'one', 'three'],
#  803: ['up', 'down', 'one', 'four'],
#  804: ['up', 'down', 'one', 'two', 'three'],
#  805: ['up', 'down', 'one', 'two', 'four'],
#  806: ['up', 'down', 'one', 'three', 'four'],
#  807: ['up', 'down', 'two', 'three'],
#  808: ['up', 'down', 'two', 'four'],
#  809: ['up', 'down', 'two', 'one'],
#  810: ['up', 'down', 'two', 'one', 'three'],
#  811: ['up', 'down', 'two', 'one', 'four'],
#  812: ['up', 'down', 'two', 'three'],
#  813: ['up', 'down', 'two', 'four'],
#  814: ['up', 'down', 'two', 'three', 'four'],
#  815: ['up', 'down', 'three', 'four'],
#  816: ['up', 'down', 'three', 'one', 'two'],
#  817: ['up', 'down', 'three', 'one'],
#  818: ['up', 'down', 'three', 'one', 'four'],
#  819: ['up', 'down', 'three', 'two'],
#  820: ['up', 'down', 'three', 'two', 'four'],
#  821: ['up', 'down', 'three', 'four'],
#  822: ['up', 'down', 'four', 'one', 'two'],
#  823: ['up', 'down', 'four', 'one', 'three'],
#  824: ['up', 'down', 'four', 'one'],
#  825: ['up', 'down', 'four', 'two', 'three'],
#  826: ['up', 'down', 'four', 'two'],
#  827: ['up', 'down', 'four', 'three'],
#  828: ['up', 'down', 'one', 'two', 'three'],
#  829: ['up', 'down', 'one', 'two', 'four'],
#  830: ['up', 'down', 'one', 'two', 'three'],
#  831: ['up', 'down', 'one', 'two', 'four'],
#  832: ['up', 'down', 'one', 'two', 'three', 'four'],
#  833: ['up', 'down', 'one', 'three', 'four'],
#  834: ['up', 'down', 'one', 'three', 'two'],
#  835: ['up', 'down', 'one', 'three', 'two', 'four'],
#  836: ['up', 'down', 'one', 'three', 'four'],
#  837: ['up', 'down', 'one', 'four', 'two', 'three'],
#  838: ['up', 'down', 'one', 'four', 'two'],
#  839: ['up', 'down', 'one', 'four', 'three'],
#  840: ['up', 'down', 'two', 'three', 'four'],
#  841: ['up', 'down', 'two', 'three', 'four'],
#  842: ['up', 'down', 'two', 'four', 'three'],
#  843: ['up', 'left', 'right', 'one'],
#  844: ['up', 'left', 'right', 'two'],
#  845: ['up', 'left', 'right', 'three'],
#  846: ['up', 'left', 'right', 'four'],
#  847: ['up', 'left', 'right', 'one', 'two'],
#  848: ['up', 'left', 'right', 'one', 'three'],
#  849: ['up', 'left', 'right', 'one', 'four'],
#  850: ['up', 'left', 'right', 'two', 'three'],
#  851: ['up', 'left', 'right', 'two', 'four'],
#  852: ['up', 'left', 'right', 'three', 'four'],
#  853: ['up', 'left', 'one'],
#  854: ['up', 'left', 'two'],
#  855: ['up', 'left', 'three'],
#  856: ['up', 'left', 'four'],
#  857: ['up', 'left', 'one', 'two'],
#  858: ['up', 'left', 'one', 'three'],
#  859: ['up', 'left', 'one', 'four'],
#  860: ['up', 'left', 'two', 'three'],
#  861: ['up', 'left', 'two', 'four'],
#  862: ['up', 'left', 'three', 'four'],
#  863: ['up', 'left', 'right', 'one'],
#  864: ['up', 'left', 'right', 'two'],
#  865: ['up', 'left', 'right', 'three'],
#  866: ['up', 'left', 'right', 'four'],
#  867: ['up', 'left', 'right', 'one', 'two'],
#  868: ['up', 'left', 'right', 'one', 'three'],
#  869: ['up', 'left', 'right', 'one', 'four'],
#  870: ['up', 'left', 'right', 'two', 'three'],
#  871: ['up', 'left', 'right', 'two', 'four'],
#  872: ['up', 'left', 'right', 'three', 'four'],
#  873: ['up', 'left', 'down', 'one'],
#  874: ['up', 'left', 'down', 'two'],
#  875: ['up', 'left', 'down', 'three'],
#  876: ['up', 'left', 'down', 'four'],
#  877: ['up', 'left', 'down', 'one', 'two'],
#  878: ['up', 'left', 'down', 'one', 'three'],
#  879: ['up', 'left', 'down', 'one', 'four'],
#  880: ['up', 'left', 'down', 'two', 'three'],
#  881: ['up', 'left', 'down', 'two', 'four'],
#  882: ['up', 'left', 'down', 'three', 'four'],
#  883: ['up', 'left', 'down', 'right', 'one'],
#  884: ['up', 'left', 'down', 'right', 'two'],
#  885: ['up', 'left', 'down', 'right', 'three'],
#  886: ['up', 'left', 'down', 'right', 'four'],
#  887: ['up', 'left', 'down', 'right', 'one', 'two'],
#  888: ['up', 'left', 'down', 'right', 'one', 'three'],
#  889: ['up', 'left', 'down', 'right', 'one', 'four'],
#  890: ['up', 'left', 'down', 'right', 'two', 'three'],
#  891: ['up', 'left', 'down', 'right', 'two', 'four'],
#  892: ['up', 'left', 'down', 'right', 'three', 'four'],
#  893: ['up', 'left', 'one', 'two'],
#  894: ['up', 'left', 'one', 'three'],
#  895: ['up', 'left', 'one', 'four'],
#  896: ['up', 'left', 'one', 'two'],
#  897: ['up', 'left', 'one', 'three'],
#  898: ['up', 'left', 'one', 'four'],
#  899: ['up', 'left', 'one', 'two', 'three'],
#  900: ['up', 'left', 'one', 'two', 'four'],
#  901: ['up', 'left', 'one', 'three', 'four'],
#  902: ['up', 'left', 'two', 'three'],
#  903: ['up', 'left', 'two', 'four'],
#  904: ['up', 'left', 'two', 'one'],
#  905: ['up', 'left', 'two', 'one', 'three'],
#  906: ['up', 'left', 'two', 'one', 'four'],
#  907: ['up', 'left', 'two', 'three'],
#  908: ['up', 'left', 'two', 'four'],
#  909: ['up', 'left', 'two', 'three', 'four'],
#  910: ['up', 'left', 'three', 'four'],
#  911: ['up', 'left', 'three', 'one', 'two'],
#  912: ['up', 'left', 'three', 'one'],
#  913: ['up', 'left', 'three', 'one', 'four'],
#  914: ['up', 'left', 'three', 'two'],
#  915: ['up', 'left', 'three', 'two', 'four'],
#  916: ['up', 'left', 'three', 'four'],
#  917: ['up', 'left', 'four', 'one', 'two'],
#  918: ['up', 'left', 'four', 'one', 'three'],
#  919: ['up', 'left', 'four', 'one'],
#  920: ['up', 'left', 'four', 'two', 'three'],
#  921: ['up', 'left', 'four', 'two'],
#  922: ['up', 'left', 'four', 'three'],
#  923: ['up', 'left', 'one', 'two', 'three'],
#  924: ['up', 'left', 'one', 'two', 'four'],
#  925: ['up', 'left', 'one', 'two', 'three'],
#  926: ['up', 'left', 'one', 'two', 'four'],
#  927: ['up', 'left', 'one', 'two', 'three', 'four'],
#  928: ['up', 'left', 'one', 'three', 'four'],
#  929: ['up', 'left', 'one', 'three', 'two'],
#  930: ['up', 'left', 'one', 'three', 'two', 'four'],
#  931: ['up', 'left', 'one', 'three', 'four'],
#  932: ['up', 'left', 'one', 'four', 'two', 'three'],
#  933: ['up', 'left', 'one', 'four', 'two'],
#  934: ['up', 'left', 'one', 'four', 'three'],
#  935: ['up', 'left', 'two', 'three', 'four'],
#  936: ['up', 'left', 'two', 'three', 'four'],
#  937: ['up', 'left', 'two', 'four', 'three'],
#  938: ['up', 'right', 'left', 'one'],
#  939: ['up', 'right', 'left', 'two'],
#  940: ['up', 'right', 'left', 'three'],
#  941: ['up', 'right', 'left', 'four'],
#  942: ['up', 'right', 'left', 'one', 'two'],
#  943: ['up', 'right', 'left', 'one', 'three'],
#  944: ['up', 'right', 'left', 'one', 'four'],
#  945: ['up', 'right', 'left', 'two', 'three'],
#  946: ['up', 'right', 'left', 'two', 'four'],
#  947: ['up', 'right', 'left', 'three', 'four'],
#  948: ['up', 'right', 'one'],
#  949: ['up', 'right', 'two'],
#  950: ['up', 'right', 'three'],
#  951: ['up', 'right', 'four'],
#  952: ['up', 'right', 'one', 'two'],
#  953: ['up', 'right', 'one', 'three'],
#  954: ['up', 'right', 'one', 'four'],
#  955: ['up', 'right', 'two', 'three'],
#  956: ['up', 'right', 'two', 'four'],
#  957: ['up', 'right', 'three', 'four'],
#  958: ['up', 'right', 'down', 'left', 'one'],
#  959: ['up', 'right', 'down', 'left', 'two'],
#  960: ['up', 'right', 'down', 'left', 'three'],
#  961: ['up', 'right', 'down', 'left', 'four'],
#  962: ['up', 'right', 'down', 'left', 'one', 'two'],
#  963: ['up', 'right', 'down', 'left', 'one', 'three'],
#  964: ['up', 'right', 'down', 'left', 'one', 'four'],
#  965: ['up', 'right', 'down', 'left', 'two', 'three'],
#  966: ['up', 'right', 'down', 'left', 'two', 'four'],
#  967: ['up', 'right', 'down', 'left', 'three', 'four'],
#  968: ['up', 'right', 'down', 'one'],
#  969: ['up', 'right', 'down', 'two'],
#  970: ['up', 'right', 'down', 'three'],
#  971: ['up', 'right', 'down', 'four'],
#  972: ['up', 'right', 'down', 'one', 'two'],
#  973: ['up', 'right', 'down', 'one', 'three'],
#  974: ['up', 'right', 'down', 'one', 'four'],
#  975: ['up', 'right', 'down', 'two', 'three'],
#  976: ['up', 'right', 'down', 'two', 'four'],
#  977: ['up', 'right', 'down', 'three', 'four'],
#  978: ['up', 'right', 'one', 'two'],
#  979: ['up', 'right', 'one', 'three'],
#  980: ['up', 'right', 'one', 'four'],
#  981: ['up', 'right', 'one', 'two'],
#  982: ['up', 'right', 'one', 'three'],
#  983: ['up', 'right', 'one', 'four'],
#  984: ['up', 'right', 'one', 'two', 'three'],
#  985: ['up', 'right', 'one', 'two', 'four'],
#  986: ['up', 'right', 'one', 'three', 'four'],
#  987: ['up', 'right', 'two', 'three'],
#  988: ['up', 'right', 'two', 'four'],
#  989: ['up', 'right', 'two', 'one'],
#  990: ['up', 'right', 'two', 'one', 'three'],
#  991: ['up', 'right', 'two', 'one', 'four'],
#  992: ['up', 'right', 'two', 'three'],
#  993: ['up', 'right', 'two', 'four'],
#  994: ['up', 'right', 'two', 'three', 'four'],
#  995: ['up', 'right', 'three', 'four'],
#  996: ['up', 'right', 'three', 'one', 'two'],
#  997: ['up', 'right', 'three', 'one'],
#  998: ['up', 'right', 'three', 'one', 'four'],
#  999: ['up', 'right', 'three', 'two'],
#  1000: ['up', 'right', 'three', 'two', 'four'],
#  1001: ['up', 'right', 'three', 'four'],
#  1002: ['up', 'right', 'four', 'one', 'two'],
#  1003: ['up', 'right', 'four', 'one', 'three'],
#  1004: ['up', 'right', 'four', 'one'],
#  1005: ['up', 'right', 'four', 'two', 'three'],
#  1006: ['up', 'right', 'four', 'two'],
#  1007: ['up', 'right', 'four', 'three'],
#  1008: ['up', 'right', 'one', 'two', 'three'],
#  1009: ['up', 'right', 'one', 'two', 'four'],
#  1010: ['up', 'right', 'one', 'two', 'three'],
#  1011: ['up', 'right', 'one', 'two', 'four'],
#  1012: ['up', 'right', 'one', 'two', 'three', 'four'],
#  1013: ['up', 'right', 'one', 'three', 'four'],
#  1014: ['up', 'right', 'one', 'three', 'two'],
#  1015: ['up', 'right', 'one', 'three', 'two', 'four'],
#  1016: ['up', 'right', 'one', 'three', 'four'],
#  1017: ['up', 'right', 'one', 'four', 'two', 'three']}

# %%
def generate_combinations_with_indices(start_index=18):
    # Define the walking directions and attack buttons as before
    walking_directions = ["up", "down", "left", "right", "up, left", "up, right", "down, left", "down, right"]
    attack_buttons = ["one", "two", "three", "four", "one, two", "one, three", "one, four", "two, three", "two, four", "three, four"]

    # Create a list to hold the formatted combinations
    combinations_with_indices = []

    # Current index to assign to each combination
    current_index = start_index

    # Generate combinations
    for walking in walking_directions:
        for attack in attack_buttons:
            combination = f"{current_index}: [{walking}] + [{attack}]"
            combinations_with_indices.append(combination)
            current_index += 1  # Increment index for the next combination
    
    return combinations_with_indices

# Generate and display the first 10 combinations with their indices starting from 18
print(generate_combinations_with_indices())
# Out:
# ['18: [up] + [one]', '19: [up] + [two]', '20: [up] + [three]', '21: [up] + [four]', '22: [up] + [one, two]', '23: [up] + [one, three]', '24: [up] + [one, four]', '25: [up] + [two, three]', '26: [up] + [two, four]', '27: [up] + [three, four]', '28: [down] + [one]', '29: [down] + [two]', '30: [down] + [three]', '31: [down] + [four]', '32: [down] + [one, two]', '33: [down] + [one, three]', '34: [down] + [one, four]', '35: [down] + [two, three]', '36: [down] + [two, four]', '37: [down] + [three, four]', '38: [left] + [one]', '39: [left] + [two]', '40: [left] + [three]', '41: [left] + [four]', '42: [left] + [one, two]', '43: [left] + [one, three]', '44: [left] + [one, four]', '45: [left] + [two, three]', '46: [left] + [two, four]', '47: [left] + [three, four]', '48: [right] + [one]', '49: [right] + [two]', '50: [right] + [three]', '51: [right] + [four]', '52: [right] + [one, two]', '53: [right] + [one, three]', '54: [right] + [one, four]', '55: [right] + [two, three]', '56: [right] + [two, four]', '57: [right] + [three, four]', '58: [up, left] + [one]', '59: [up, left] + [two]', '60: [up, left] + [three]', '61: [up, left] + [four]', '62: [up, left] + [one, two]', '63: [up, left] + [one, three]', '64: [up, left] + [one, four]', '65: [up, left] + [two, three]', '66: [up, left] + [two, four]', '67: [up, left] + [three, four]', '68: [up, right] + [one]', '69: [up, right] + [two]', '70: [up, right] + [three]', '71: [up, right] + [four]', '72: [up, right] + [one, two]', '73: [up, right] + [one, three]', '74: [up, right] + [one, four]', '75: [up, right] + [two, three]', '76: [up, right] + [two, four]', '77: [up, right] + [three, four]', '78: [down, left] + [one]', '79: [down, left] + [two]', '80: [down, left] + [three]', '81: [down, left] + [four]', '82: [down, left] + [one, two]', '83: [down, left] + [one, three]', '84: [down, left] + [one, four]', '85: [down, left] + [two, three]', '86: [down, left] + [two, four]', '87: [down, left] + [three, four]', '88: [down, right] + [one]', '89: [down, right] + [two]', '90: [down, right] + [three]', '91: [down, right] + [four]', '92: [down, right] + [one, two]', '93: [down, right] + [one, three]', '94: [down, right] + [one, four]', '95: [down, right] + [two, three]', '96: [down, right] + [two, four]', '97: [down, right] + [three, four]']
